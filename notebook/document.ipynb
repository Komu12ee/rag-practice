# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a test document.",

    metadata={"source": "test_source",
              "page": 1,
              "author": "test_author",
              "date": "2024-06-01"}
)
doc
# Out:
# Document(metadata={'source': 'test_source', 'page': 1, 'author': 'test_author', 'date': '2024-06-01'}, page_content='This is a test document.')

# %%
## create a text file 
import os
os.makedirs("../data/text_file", exist_ok=True)

# %%
sample_text = {
    "../data/text_file/sample.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support
"""
}

for file_path, content in sample_text.items():
    with open(file_path, "w",encoding="utf-8") as f:
        f.write(content)
print("Sample text file created successfully.")
# Out:
# Sample text file created successfully.

# %%
# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14604\915259760.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/text_file/sample.txt")
loader.load()
# Out:
# [Document(metadata={'source': '../data/text_file/sample.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n')]

# %%
from langchain_community.document_loaders import DirectoryLoader
directory_loader = DirectoryLoader("../data/text_file",
 glob="*.txt",
 loader_cls=TextLoader,
 loader_kwargs={"encoding": "utf-8"},
 show_progress=False
 )
directory_loader.load()
# Out:
# [Document(metadata={'source': '..\\data\\text_file\\ml.txt'}, page_content='hii my name is komendra'),
#  Document(metadata={'source': '..\\data\\text_file\\sample.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n')]

# %%
import sys
import subprocess
import ensurepip

try:
    import pip
except ImportError:
    ensurepip.bootstrap()

subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "pip"])
subprocess.check_call([sys.executable, "-m", "pip", "install", "pymupdf"])
print('Installed pymupdf into:', sys.executable)
# Out:
# Installed pymupdf into: c:\Users\hp\Desktop\rag\.venv\Scripts\python.exe

# %%
from langchain_community.document_loaders import DirectoryLoader, PyMuPDFLoader
# directory_loader = DirectoryLoader("../data/pdf_file",
#  glob="**/*.pdf",
#  loader_cls=PyMuPDFLoader,
# #  loader_kwargs={"encoding": "utf-8"},
#  show_progress=False
#  )
# document_pdf = directory_loader.load()
# document_pdf
directory_loader = DirectoryLoader(
    "../data/pdf_file",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)
document_pdf = directory_loader.load()
document_pdf
# Out:
# Error loading file ..\data\pdf_file\5CD6023KGS.pdf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\hp\Desktop\rag\.venv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:953, in PyMuPDFParser._lazy_parse(self, blob, text_kwargs)
#     952 try:
# --> 953     import pymupdf
#     955     text_kwargs = text_kwargs or self.text_kwargs
#
# File c:\Users\hp\Desktop\rag\.venv\Lib\site-packages\pymupdf\__init__.py:33
#      31 import zipfile
#      32
# ---> 33 from . import extra
#      34
#
# File c:\Users\hp\Desktop\rag\.venv\Lib\site-packages\pymupdf\extra.py:10
#       9 if getattr(globals().get("__spec__"), "parent", None) or __package__ or "." in __name__:
# ---> 10     from . import _extra
#      11 else:
#
# ImportError: DLL load failed while importing _extra: The specified module could not be found.
#
# ...
